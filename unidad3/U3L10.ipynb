# %% [markdown]
# # FASES DEL APRENDIZAJE SUPERVISADO

# %% [markdown]
# # Fase 1: Recopilación de los datos

# %% [markdown]
# # Fase 2: Exploración y preparación de los datos

# %% [markdown]
# ## Selección de características

# %% [markdown]
# ## Nulos

# %% [markdown]
# ## Únicos

# %% [markdown]
# ## Duplicados

# %% [markdown]
# ## Distribuciones

# %% [markdown]
# ## Correlaciones con la variable objectivo

# %% [markdown]
# ## Equilibrio

# %% [markdown]
# ## Outliers

# %% [markdown]
# # Fase 3: División de los datos

# %% [markdown]
# ## Encoders

# %% [markdown]
# ## Correlaciones

# %% [markdown]
# ## Normalización y escalado

# %% [markdown]
# # Fase 4: Entrenamiento del modelo y realización de las predicciones

# %% [markdown]
# # Fase 5: Validación del modelo

# %% [markdown]
# #Fase 6: Optimitzación del modelo

# %% [markdown]
# # Fase 7: Validación del nuevo modelo

# %% [markdown]
# # Fase 8: Conclusiones

# %% [markdown]
# # Fase 9: Pruebas

# %% [markdown]
# ## Guardar el modelo

# %% [markdown]
# ## Comprobación del sobreajuste

# %% [markdown]
# ## Nuevas predicciones
