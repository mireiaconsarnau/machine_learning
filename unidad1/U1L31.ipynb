# %% [markdown]
# # Introducción al formato Markdown en Google Colab

# %% [markdown]
# Este es un ejemplo práctico para aprender a usar **Markdown** y mejorar la presentación de tus notebooks en Google Colab. A continuación verás las opciones más básicas y útiles.

# %% [markdown]
# ## Formatos de texto

# %% [markdown]
# Puedes aplicar varios estilos:
#
# - *Cursiva*: *este texto está en cursiva*
# - **Negrita**: **este texto está en negrita**
# - **_Negrita y cursiva combinadas_**
# - ~~Texto tachado~~ (puede no verse bien en todos los entornos)

# %% [markdown]
# ## Listas

# %% [markdown]
# ### Lista con viñetas
#
# - Elemento 1
# - Elemento 2
# - Elemento 3

# %% [markdown]
# ### Lista numerada
#
# 1. Paso uno
# 2. Paso dos
# 3. Paso tres

# %% [markdown]
# ## Bloques de código

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# ## Enlaces

# %% [markdown]
# [Ir a Google](https://www.google.com)

# %% [markdown]
# ## Tablas

# %% [markdown]
# | Nombre  | Nota | Estado       |
# |---------|------|--------------|
# | Lucía   | 9.0  | **Aprobado** |
# | Diego   | 5.2  | *Pendiente*  |
# | Marta   | 3.8  | **Suspendido** |

# %% [markdown]
# ## Citas

# %% [markdown]
# > Esto es una cita. Útil para destacar ideas clave o frases importantes.

# %% [markdown]
# # Cargar datos desde un csv

# %%
# Importación de la biblioteca
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

ruta = '/content/drive/MyDrive/CURSO_MACHINE_LEARNING/CSV/datos.csv'
df = pd.read_csv(ruta)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df
# Out:
#    id   nombre  edad  ingresos  compra
# 0   1    Laura    34      2100       1
# 1   2    Pedro    45      1800       0
# 2   3      Ana    29      3200       1
# 3   4    David    53      1500       0
# 4   5    Marta    26      2700       1
# 5   6    Jorge    38      2000       0
# 6   7     Sara    41      2500       1
# 7   8   Manuel    30      1900       0
# 8   9    Elena    22      2300       1
# 9  10  Ricardo    60      1700       0
